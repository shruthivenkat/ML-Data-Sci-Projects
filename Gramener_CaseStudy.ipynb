# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
loan = pd.read_csv(r"C:\Users\pc-pc\Downloads\loan\loan1.csv")
# Out:
# C:\Users\pc-pc\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
loan.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade            ...              \
# 0   10.65%       162.87     B        B2            ...
# 1   15.27%        59.83     C        C4            ...
# 2   15.96%        84.33     C        C5            ...
# 3   13.49%       339.31     C        C1            ...
# 4   12.69%        67.79     B        B5            ...
#
#   num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                NaN                NaN            NaN               NaN
# ...

# %%
loan.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)

# %%
#Dropping columns has all values as NA
loan.dropna(axis=1,how='all',inplace=True)

# %%
len(loan.columns)
# Out:
# 57

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 57 columns):
# id                            39717 non-null int64
# member_id                     39717 non-null int64
# loan_amnt                     39717 non-null int64
# funded_amnt                   39717 non-null int64
# funded_amnt_inv               39717 non-null float64
# term                          39717 non-null object
# int_rate                      39717 non-null object
# installment                   39717 non-null float64
# grade                         39717 non-null object
# sub_grade                     39717 non-null object
# emp_title                     37258 non-null object
# emp_length                    38642 non-null object
# home_ownership                39717 non-null object
# annual_inc                    39717 non-null float64
# verification_status           39717 non-null object
# issue_d                       39717 non-null object
# ...

# %%
#columns has less values 
#gram.drop(columns=['desc','mths_since_last_delinq','mths_since_last_record','next_pymnt_d'], axis=1, inplace= True)

# %%
#gram.info()

# %%
loan.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
loan.to_csv(r'C:\Users\sateesh\Desktop\pws\loan\loan_modified.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-c9555a2842e1> in <module>()
# ----> 1 loan.to_csv(r'C:\Users\sateesh\Desktop\pws\loan\loan_modified.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     134             f, handles = _get_handle(self.path_or_buf, self.mode,
# ...

# %%
loan.columns

# %%
# Taking only data which has loan status as charged off
loan_ChargeOff = loan[loan.loan_status == 'Charged Off']

# %%
#no duplicates
loan_ChargeOff[loan_ChargeOff.duplicated()]

# %%
loan_ChargeOff.info()

# %%
# dropping desc as it will not have any impact on charge off
# dropping next_paymnt_d as it has zero values
loan_ChargeOff.drop(columns=['desc','next_pymnt_d'], axis=1, inplace= True)

# %%
loan_ChargeOff.to_csv(r'C:\Users\sateesh\Desktop\pws\loan\loan_ChargeOff.csv')

# %%
loan.term.unique()

# %%
#Found mixed types of columns like term,int_rate,emp_length,rev_util
loan_ChargeOff.term = loan_ChargeOff.term.apply(lambda x: 60 if x  == ' 60 months' else 36 )

loan_ChargeOff.int_rate = loan_ChargeOff.int_rate.apply(lambda x: x.split('%')[0]) 

loan_ChargeOff.emp_length = loan_ChargeOff.emp_length.astype(str).apply(lambda x: x.split(' ')[1] if len(x.split(' ')) == 3 else x.split(' ')[0])
loan_ChargeOff.emp_length = loan_ChargeOff.emp_length.astype(str).apply(lambda x: x.split('+')[0])

loan_ChargeOff.revol_util = loan_ChargeOff.revol_util.astype(str).apply(lambda x: x.split('%')[0])

# %%
loan_ChargeOff.info()

# %%
#date conversion 
loan_ChargeOff.issue_d = pd.to_datetime(loan_ChargeOff.issue_d, format='%b-%y')

loan_ChargeOff.earliest_cr_line = pd.to_datetime(loan_ChargeOff.earliest_cr_line, format='%b-%y')

loan_ChargeOff.last_pymnt_d = pd.to_datetime(loan_ChargeOff.last_pymnt_d, format='%b-%y')

loan_ChargeOff.last_credit_pull_d = pd.to_datetime(loan_ChargeOff.last_credit_pull_d, format='%b-%y')

# %%
loan_ChargeOff.info()

# %%
#10+ years emp_length are more charged off
sns.countplot(loan_ChargeOff.emp_length)

# %%
plt.figure(figsize=(12,6))
sns.countplot(y=loan.emp_length,hue= loan.loan_status )

# %%
# 36 months has more charged off
sns.countplot(loan_ChargeOff.term)

# %%
# grade B has more charged off
sns.countplot(loan_ChargeOff.grade)

# %%
# sub-grade B5 has more charged off
plt.figure(figsize=(12,6))
sns.countplot(loan_ChargeOff.sub_grade)

# %%
#Rented home has more charged off
sns.countplot(loan_ChargeOff.home_ownership )

# %%
sns.countplot(loan.home_ownership,hue= loan.loan_status )

# %%
#Not verified Status has more charged off
sns.countplot(loan_ChargeOff.verification_status )

# %%
sns.countplot(loan.verification_status,hue= loan.loan_status )

# %%
#non of them have payment plan, who charged off 
sns.countplot(loan_ChargeOff.pymnt_plan )

# %%
#none of them has payment plan
sns.countplot(loan.pymnt_plan )

# %%
# dept_consolidation has more charged off
sns.countplot(y=loan_ChargeOff.purpose)

# %%
plt.figure(figsize=(12,6))
sns.countplot(y=loan.purpose,hue= loan.loan_status)

# %%
# charged off's are individual application type
sns.countplot(loan_ChargeOff.application_type)

# %%
# all are individual application types
sns.countplot(loan.application_type )

# %%
# dropping application_type, pymnt_plan as all the applications are individual and they dont have any payment plan
loan_ChargeOff.drop(columns=['application_type','pymnt_plan'], axis=1, inplace= True)

# %%
loan_ChargeOff.info()

# %%
help(sns.countplot)

# %%
plt.figure(figsize=(20,20))
plt.matshow(gram.corr())
plt.show()

# %%
plt.figure(figsize=(15,15))
corr = loan_ChargeOff.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,cmap="YlGnBu")
